# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# 1. Carregar dados (primeiras 500 amostras)
X_train = np.load('../../iot-ids-research/data/processed/binary/X_train_binary.npy')[:500]
print(f"Shape dos dados: {X_train.shape}")
# Out:
# Shape dos dados: (500, 39)

# %%
# Rodar DBSCAN
dbscan = DBSCAN(eps=2.0, min_samples=5)
labels_dbscan = dbscan.fit_predict(X_scaled)

# Analisar resultados
n_clusters = len(set(labels_dbscan)) - (1 if -1 in labels_dbscan else 0)
n_noise = list(labels_dbscan).count(-1)

print(f"Clusters encontrados: {n_clusters}")
print(f"Pontos marcados como ruído (outliers): {n_noise}")
print(f"Distribuição: {np.bincount(labels_dbscan[labels_dbscan >= 0])}")
# Out:
# Clusters encontrados: 15
# Pontos marcados como ruído (outliers): 82
# Distribuição: [86 33 67 25 84  6 67  7  5  6  5  8  7  7  5]

# %%
# Rodar DBSCAN
dbscan = DBSCAN(eps=1.0, min_samples=5)
labels_dbscan = dbscan.fit_predict(X_scaled)

# Analisar resultados
n_clusters = len(set(labels_dbscan)) - (1 if -1 in labels_dbscan else 0)
n_noise = list(labels_dbscan).count(-1)

print(f"Clusters encontrados: {n_clusters}")
print(f"Pontos marcados como ruído (outliers): {n_noise}")
print(f"Distribuição: {np.bincount(labels_dbscan[labels_dbscan >= 0])}")
# Out:
# Clusters encontrados: 13
# Pontos marcados como ruído (outliers): 110
# Distribuição: [81 32  5 25 81 62 66  7  5  5  8  6  7]

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# DBSCAN é sensível à escala - normalizar primeiro
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_train)

# Rodar DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels_dbscan = dbscan.fit_predict(X_scaled)

# Analisar resultados
n_clusters = len(set(labels_dbscan)) - (1 if -1 in labels_dbscan else 0)
n_noise = list(labels_dbscan).count(-1)

print(f"Clusters encontrados: {n_clusters}")
print(f"Pontos marcados como ruído (outliers): {n_noise}")
print(f"Distribuição: {np.bincount(labels_dbscan[labels_dbscan >= 0])}")
# Out:
# Clusters encontrados: 12
# Pontos marcados como ruído (outliers): 143
# Distribuição: [77 32 25 67 57 65  5  7  5  5  7  5]

# %%
# Rodar DBSCAN
dbscan = DBSCAN(eps=0.3, min_samples=5)
labels_dbscan = dbscan.fit_predict(X_scaled)

# Analisar resultados
n_clusters = len(set(labels_dbscan)) - (1 if -1 in labels_dbscan else 0)
n_noise = list(labels_dbscan).count(-1)

print(f"Clusters encontrados: {n_clusters}")
print(f"Pontos marcados como ruído (outliers): {n_noise}")
print(f"Distribuição: {np.bincount(labels_dbscan[labels_dbscan >= 0])}")
# Out:
# Clusters encontrados: 10
# Pontos marcados como ruído (outliers): 184
# Distribuição: [63  6 30 23 60 52 65  5  6  6]
